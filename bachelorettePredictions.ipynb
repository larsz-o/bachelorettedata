# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./bachelorette.csv')

# %%
df.head(30)
# Out:
#             SHOW  SEASON     CONTESTANT ELIMINATION-1 ELIMINATION-2  \
# 0           SHOW  SEASON             ID             1             2
# 1   Bachelorette      13     13_BRYAN_A            R1           NaN
# 2   Bachelorette      13     13_PETER_K           NaN             R
# 3   Bachelorette      13      13_ERIC_B           NaN           NaN
# 4   Bachelorette      13      13_DEAN_U           NaN             R
# 5   Bachelorette      13      13_ADAM_G           NaN           NaN
# 6   Bachelorette      13      13_MATT_M           NaN           NaN
# 7   Bachelorette      13      13_ALEX_B           NaN           NaN
# 8   Bachelorette      13      13_WILL_G           NaN           NaN
# 9   Bachelorette      13     13_KENNY_L           NaN           NaN
# 10  Bachelorette      13   13_ANTHONY_B           NaN           NaN
# 11  Bachelorette      13    13_JOSIAH_G           NaN             R
# 12  Bachelorette      13       13_LEE_G           NaN           NaN
# ...

# %%
df = df[["CONTESTANT","ELIMINATION-1", "ELIMINATION-10" ]]

# %%
firstImpression = df[df["ELIMINATION-1"] == "R1"]

# %%
firstImpression
# Out:
#          CONTESTANT ELIMINATION-1 ELIMINATION-10
# 1        13_BRYAN_A            R1              W
# 33      12_JORDAN_R            R1              W
# 60       11_SHAWN_B            R1            NaN
# 88        10_NICK_V            R1             EU
# 114       09_DREW_K            R1             ED
# 116        09_ZAK_W            R1            NaN
# 117    09_MICHAEL_G            R1            NaN
# 122        09_BEN_S            R1            NaN
# 123     09_BRYDEN_V            R1            NaN
# 129       09_NICK_M            R1            NaN
# 144       08_DOUG_C            R1            NaN
# 170       07_RYAN_P            R1            NaN
# 191     06_ROBERT_M            R1              W
# 227      05_DAVID_G            R1            NaN
# 248      04_JESSE_C            R1            NaN
# 250     04_JEREMY_A            R1            NaN
# 259    04_RICHARD_M            R1            NaN
# 281        03_KEITH            R1            NaN
# ...

# %%
firstImpression = firstImpression[firstImpression["ELIMINATION-10"] == "W"]

# %%
firstImpression
# Out:
#          CONTESTANT ELIMINATION-1 ELIMINATION-10
# 1        13_BRYAN_A            R1              W
# 33      12_JORDAN_R            R1              W
# 191     06_ROBERT_M            R1              W
# 352    21_VANESSA_G            R1              W
# 471  17_CATHERINE_G            R1              W
